# %%
import random
random.randint(50000, 100000)
# Out:
# 97095

# %%
[random.randint(50000, 100000) for _ in range (1_000_000)]
# Out:
# [81501,
#  51686,
#  96087,
#  67317,
#  81307,
#  67226,
#  75676,
#  59169,
#  98392,
#  79015,
#  53145,
#  55631,
#  94493,
#  52016,
#  71689,
#  88875,
#  60869,
#  80340,
#  57979,
#  88416,
#  80714,
#  78019,
#  74767,
#  74121,
#  85658,
#  71103,
#  66412,
#  87030,
#  59499,
#  74153,
#  56729,
#  61161,
#  74030,
#  65995,
#  63312,
#  74140,
#  99715,
#  64137,
#  68119,
#  97120,
#  64585,
#  99515,
#  63214,
#  88417,
#  84022,
#  72190,
#  97032,
#  62029,
#  54097,
#  57373,
#  80879,
#  88813,
#  65541,
#  59024,
#  83580,
#  89129,
#  75706,
#  53079,
#  64093,
#  65341,
#  98138,
#  50399,
#  91792,
#  62650,
#  62913,
#  95627,
#  64205,
#  74192,
#  88246,
#  79932,
#  94573,
#  94671,
#  51874,
#  52544,
#  99788,
#  60149,
#  86368,
#  57749,
#  51624,
#  85952,
#  60371,
#  73807,
#  64344,
#  87202,
#  66505,
#  64528,
#  66280,
#  99410,
#  71524,
#  82738,
#  60766,
#  95044,
#  93029,
#  52223,
#  52054,
#  54079,
#  54933,
#  89963,
#  60615,
#  67479,
# ...

# %%
salary_list = [random.randint(50000, 100000) for _ in range (1_000_000)] #assigned to salry list

# %%
import statistics
statistics.mean(salary_list) #mean
# Out:
# 75020.345363

# %%
statistics.median(salary_list) #median
# Out:
# 75007.0

# %%
statistics.mode(salary_list) #mode
# Out:
# 86177

# %%
# %%timeit
statistics.mean(salary_list) #mean
# Out:
# 205 ms ± 1.21 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
import numpy as np

# %%
# %%timeit
np.mean(salary_list)
# Out:
# 35.4 ms ± 142 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
#def core data type np
my_array = np.array([1,2,3,4])

# %%
my_array.mean()
# Out:
# 2.5

# %%
# job titles indexed at 0 through 3
job_titles = np.array(['Data Analyst','Data Scientist','Data Engineer','Machine Learning', 'AI Engineer'])
# Base salaries
base_salaries = np.array([60000, 70000, 75000, 90000, np.nan])
#bonus_rates
bonus_rates = np.array([.05, .1, .08, .12, np.nan])

# %%
total_salaries = base_salaries * (1 + bonus_rates)
total_salaries
# Out:
# array([ 63000.,  77000.,  81000., 100800.,     nan])

# %%
np.nanmean(total_salaries)
# Out:
# 80450.0

# %%
#Problem Statement: Create a NumPy array representing the number of job applications received each day for a week (7 days). 
#The array should be called applications and contain the following numbers: [10, 15, 7, 20, 25, 30, 5]. Print the array.
#Code Needed:
applications_list = [10, 15, 7, 20, 25, 30, 5]
applications = np.array(applications_list)
print(applications)
# Out:
# [10 15  7 20 25 30  5]

# %%
# Problem Statement: Create a NumPy array representing the number of job postings for different job titles called postings. 
# The array contains [10, 15, 7, 20, 25, 30, 5]. Use slicing to get the number of postings for the first three job titles.
# Code Needed:
postings_list = [10, 15, 7, 20, 25, 30, 5]
postings = np.array(postings_list)
first_three = postings[:3]
first_three
# Out:
# array([10, 15,  7])

# %%
# Problem Statement: Create a NumPy array representing the salaries called salaries offered for five different job positions. 
# Calculate the highest and lowest salary using NumPy functions. The array salaries contains [70000, 85000, 60000, 95000, 80000].

# Code Needed:
salaries_list = [70000, 85000, 60000, 95000, 80000]
salaries = np.array(salaries_list)
hi = np.max(salaries)
lo = np.min(salaries)
print(hi, lo)
# Out:
# 95000 60000

# %% [markdown]
# ### Pandas

# %%
# !pip list
# Out:
# Package                           Version
# --------------------------------- ------------------
# aext-assistant                    4.0.15
# aext-assistant-server             4.0.15
# aext-core                         4.0.15
# aext-core-server                  4.0.15
# aext-panels                       4.0.15
# aext-panels-server                4.0.15
# aext-share-notebook               4.0.15
# aext-share-notebook-server        4.0.15
# aext-shared                       4.0.15
# aiobotocore                       2.12.3
# aiohttp                           3.9.5
# aioitertools                      0.7.1
# aiosignal                         1.2.0
# alabaster                         0.7.16
# altair                            5.0.1
# anaconda-anon-usage               0.4.4
# anaconda-catalogs                 0.2.0
# anaconda-client                   1.12.3
# anaconda-cloud-auth               0.5.1
# anaconda-navigator                2.6.3
# anaconda-project                  0.11.1
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('california_housing_test.csv')
# df = pd.read_csv('your_csv_file.csv')
# print(df.head())

# %%
print(df.head())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df['total_bedrooms'] # single ' ' --> quotes means it is a string
# Out:
# 0        661.0
# 1        310.0
# 2        507.0
# 3         15.0
# 4        244.0
#          ...
# 2995     642.0
# 2996    1082.0
# 2997     201.0
# 2998      14.0
# 2999     263.0
# Name: total_bedrooms, Length: 3000, dtype: float64

# %%
df['total_bedrooms'][0]
# Out:
# 661.0

# %%
df['total_bedrooms'][2999]
# Out:
# 263.0

# %%
pip install datasets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
dfc = pd.read_csv('data_jobs.csv')

# %%
dfc.head
# Out:
# <bound method NDFrame.head of              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# ...

# %%
dfc
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
dfc.tail(5)
# Out:
#           job_title_short                                          job_title  \
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home search_location  \
# ...

# %%
r57 = dfc.job_title[56] #pandas are 0-based, meaning the 57th row is at position 56
r57
# Out:
# 'Principal Statistical Scientist'

# %%
dfc.head(7) # first 7 rows, begin at 0
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
# 5         Data Engineer                                  GCP Data Engineer
# 6  Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
#
#                    job_location             job_via         job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby                 Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México                 Full-time
# 2               Berlin, Germany        via LinkedIn                 Full-time
# ...

# %%
dfc.tail(3)
# Out:
#           job_title_short                                          job_title  \
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
#                                job_location              job_via  \
# 785738                             Malaysia     melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat  melalui Recruit.net
# 785740                                India       melalui Trigyn
#
#        job_schedule_type  job_work_from_home search_location  \
# 785738   Pekerjaan tetap               False        Malaysia
# 785739   Pekerjaan tetap               False           Sudan
# 785740   Pekerjaan tetap               False           India
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# ...

# %%
dfc[['job_title_short', 'job_location']].head() # multiple columns
# Out:
#         job_title_short                  job_location
# 0  Senior Data Engineer                 Watertown, CT
# 1          Data Analyst  Guadalajara, Jalisco, Mexico
# 2         Data Engineer               Berlin, Germany
# 3         Data Engineer               San Antonio, TX
# 4         Data Engineer                Washington, DC

# %%
dfc.iloc[90:93, 0:2] #slicing 90:92, AND ',0:2' lists out the job tile and title short
# Out:
#    job_title_short                                job_title
# 90  Data Scientist                           Data Scientist
# 91  Data Scientist                           Data Scientist
# 92   Data Engineer  Remote - Data Engineer - Permanent - W2

# %%
dfc.info() # class, type, row, columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
dfc.describe() #statistics for only the numeroical columns
# Out:
#        salary_year_avg  salary_hour_avg
# count     22003.000000     10662.000000
# mean     123286.274072        47.016598
# std       48312.449482        21.890738
# min       15000.000000         8.000000
# 25%       90000.000000        27.500000
# 50%      115000.000000        45.980000
# 75%      150000.000000        61.159996
# max      960000.000000       391.000000

# %%
dfc.job_title_short.unique()
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
dfc.job_title_short =='Data Analyst'
# Out:
# 0         False
# 1          True
# 2         False
# 3         False
# 4         False
#           ...
# 785736    False
# 785737     True
# 785738    False
# 785739    False
# 785740    False
# Name: job_title_short, Length: 785741, dtype: bool

# %%
dfc[dfc.job_title_short =='Data Analyst']
# Out:
#        job_title_short                                          job_title  \
# 1         Data Analyst                                       Data Analyst
# 12        Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18        Data Analyst                                       Data Analyst
# 31        Data Analyst                           Stage - Data Analyst F/H
# 34        Data Analyst  Data Analyst als Marketing Manager Automation ...
# ...                ...                                                ...
# 785703    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst          Expert Business Data Analyst - Now Hiring
# 785715    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                         job_location  \
# 1       Guadalajara, Jalisco, Mexico
# ...

# %%
dfc[(dfc.job_title_short =='Data Analyst') & (dfc.salary_year_avg > 100000)] # aded parenthesis PLUS use the & could use |
# Out:
#        job_title_short                                      job_title  \
# 410       Data Analyst    IT Business Lead Data Analyst - VP - Hybrid
# 1555      Data Analyst                  Data Analyst/Engineer (M/F/D)
# 1681      Data Analyst                                   Data Analyst
# 1684      Data Analyst                       Data Analyst - Data17829
# 1867      Data Analyst  Data Integration Analyst (West Coast/Chicago)
# ...                ...                                            ...
# 783588    Data Analyst                         Data Analytics Manager
# 783866    Data Analyst                Lead Credit Bureau Data Analyst
# 784033    Data Analyst                       Recruitment Data Analyst
# 785187    Data Analyst                                   Data Analyst
# 785515    Data Analyst                                   Data Analyst
#
#                        job_location               job_via job_schedule_type  \
# ...

# %%
dfc.salary_year_avg.notna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 785736    False
# 785737    False
# 785738    False
# 785739    False
# 785740    False
# Name: salary_year_avg, Length: 785741, dtype: bool

# %%
dfc[(dfc.job_title_short =='Data Analyst') & (dfc.salary_year_avg.notna())] # added parenthesis PLUS use the & could use |
# Out:
#        job_title_short                                    job_title  \
# 109       Data Analyst        Senior Supply Chain Analytics Analyst
# 180       Data Analyst                             Data Analyst III
# 410       Data Analyst  IT Business Lead Data Analyst - VP - Hybrid
# 988       Data Analyst                        DATA ANALYST (ONSITE)
# 1413      Data Analyst                          Junior BI Developer
# ...                ...                                          ...
# 784033    Data Analyst                     Recruitment Data Analyst
# 784423    Data Analyst                           Sales Data Analyst
# 784882    Data Analyst         Merchandising Analyst (Data Analyst)
# 785187    Data Analyst                                 Data Analyst
# 785515    Data Analyst                                 Data Analyst
#
#                        job_location                job_via job_schedule_type  \
# ...

# %%
# Problem Statement: Access the third row of the DataFrame using its index and display it.
# Hint: Use the iloc method to access the row by its index.
dfc.iloc[2]
# Out:
# job_title_short                                              Data Engineer
# job_title                Data Engineer/Scientist/Analyst, Mid or Senior...
# job_location                                               Berlin, Germany
# job_via                                                       via LinkedIn
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                    Germany
# job_posted_date                                        2023-10-10 13:14:55
# job_no_degree_mention                                                False
# job_health_insurance                                                 False
# job_country                                                        Germany
# salary_rate                                                            NaN
# ...

# %%
# Problem Statement: Display the unique job titles in the job_country column.
# Hint:Use the unique method to get the unique values of the job_country column.
dfc.job_country.unique()
# Out:
# array(['United States', 'Mexico', 'Germany', 'Sudan', 'Romania',
#        'Denmark', 'Switzerland', 'France', 'Brazil', 'United Kingdom',
#        'India', 'Poland', 'Belgium', 'Russia', 'Serbia', 'Singapore',
#        'Costa Rica', 'Ireland', 'Italy', 'Malaysia', 'Canada', 'Uruguay',
#        'Namibia', 'Estonia', 'Israel', 'Hungary', 'Austria',
#        'Philippines', 'Egypt', 'Australia', 'Chile', 'Spain',
#        'Netherlands', 'South Africa', 'Colombia', 'Hong Kong', 'Kuwait',
#        'Finland', 'Luxembourg', 'China', 'Puerto Rico', 'Sweden',
#        'Saudi Arabia', 'Argentina', 'Turkey', 'Panama', 'Nigeria',
#        'New Zealand', 'Ukraine', 'Jordan', 'United Arab Emirates',
#        'Armenia', 'Pakistan', 'Lesotho', 'Mauritius', 'Portugal',
#        'Bahrain', 'Taiwan', "Côte d'Ivoire", 'U.S. Virgin Islands',
#        'Réunion', 'Kazakhstan', 'Lithuania', 'Moldova', 'Belarus',
#        'Cyprus', 'Bulgaria', 'Honduras', 'Czechia', 'Peru', 'South Korea',
# ...

# %%
# Problem Statement:Display the first 3 rows of the DataFrame where the job_schedule_type is 'Full-time'.
# Hint:Use boolean indexing to filter the DataFrame based on the job_schedule_type column 
# and then use the head method to display the first 3 rows.
dfc[(dfc.job_schedule_type =='Full-time')].head(3)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
#
#                    job_location           job_via job_schedule_type  \
# 0                 Watertown, CT   via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico  via BeBee México         Full-time
# 2               Berlin, Germany      via LinkedIn         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# 0               False  Texas, United States  2023-06-16 13:44:15
# 1               False                Mexico  2023-01-14 13:18:07
# 2               False               Germany  2023-10-10 13:14:55
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# ...

# %%
# Problem Statement: Check for missing values in the <job_skills> column and display the rows where the values are not NA.
# Hint: Use the notna method to check for not NA values and boolean indexing to filter the DataFrame.
dfc[(dfc.job_skills.notna())]
#dfc[(dfc.job_title_short =='Data Analyst') & (dfc.salary_year_avg.notna())]
#dfc[dfc['job_skills'].notna()]
dfc
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %% [markdown]
# ### Data Cleaning

# %%
dfc.job_posted_date[0] # string becasue of single quotes, ' '
# Out:
# '2023-06-16 13:44:15'

# %%
pd.to_datetime(dfc.job_posted_date)
# Out:
# 0        2023-06-16 13:44:15
# 1        2023-01-14 13:18:07
# 2        2023-10-10 13:14:55
# 3        2023-07-04 13:01:41
# 4        2023-08-07 14:29:36
#                  ...
# 785736   2023-03-13 06:16:16
# 785737   2023-03-12 06:18:18
# 785738   2023-03-12 06:32:36
# 785739   2023-03-12 06:32:15
# 785740   2023-03-13 06:16:31
# Name: job_posted_date, Length: 785741, dtype: datetime64[ns]

# %%
dfc['job_posted_date'] = pd.to_datetime(dfc.job_posted_date) # reassign job_post_date to itself as a datetime

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
dfc.job_posted_date.dt.month
# Out:
# 0          6
# 1          1
# 2         10
# 3          7
# 4          8
#           ..
# 785736     3
# 785737     3
# 785738     3
# 785739     3
# 785740     3
# Name: job_posted_date, Length: 785741, dtype: int32

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
dfc['job_posted_month'] = dfc.job_posted_date.dt.month 
#create a new column that stores job_posted_date as the month posted - see above

# %%
dfc.sort_values(by='job_posted_date', inplace=True)

# %%
dfc
# Out:
#                   job_title_short  \
# 108804               Data Analyst
# 96906                Data Analyst
# 98438                Data Analyst
# 110290               Data Analyst
# 72158         Senior Data Analyst
# ...                           ...
# 362129              Data Engineer
# 351830              Data Engineer
# 327439              Data Engineer
# 112373        Senior Data Analyst
# 90102   Machine Learning Engineer
#
#                                                 job_title  \
# 108804                                       Data Analyst
# 96906                                        Data Analyst
# 98438                                        Data Analyst
# 110290                                       Data Analyst
# 72158           Senior Data Analyst / Platform Experience
# ...                                                   ...
# 362129                                      Data engineer
# 351830                                      Data engineer
# ...

# %%
dfc.drop(labels='salary_hour_avg', axis=1, inplace=True)
dfc.head(4)
#drop column 'salary_hour_avg' and permnanently delete with inplace=True
# Out:
#        job_title_short     job_title    job_location            job_via  \
# 108804    Data Analyst  Data Analyst    New York, NY  via CareerBuilder
# 96906     Data Analyst  Data Analyst  Bloomfield, CT  via CareerBuilder
# 98438     Data Analyst  Data Analyst  Washington, DC  via CareerBuilder
# 110290    Data Analyst  Data Analyst     Fairfax, VA  via CareerBuilder
#
#        job_schedule_type  job_work_from_home          search_location  \
# 108804         Full-time               False  New York, United States
# 96906          Full-time               False  New York, United States
# 98438          Full-time               False  New York, United States
# 110290         Full-time               False  New York, United States
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 108804 2023-01-01 00:00:04                  False                 False
# 96906  2023-01-01 00:00:07                   True                 False
# ...

# %%
dfc.dropna(subset=['salary_year_avg'], inplace=True)

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22003 entries, 108883 to 327439
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  datetime64[ns]
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  company_name           22003 non-null  object
# ...

# %%
# Problem Statement:Sort the DataFrame by salary_year_avg in descending order and display the first 10 rows.
# Hint:Use the sort_values method to sort the DataFrame by salary_year_avg in descending order.
dfc.sort_values(by='salary_year_avg').head(10)
# Out:
#          job_title_short                                          job_title  \
# 665729     Data Engineer                             Data Engineer - Hadoop
# 380187  Business Analyst                                 Operations Analyst
# 130855     Data Engineer                    Showwcase Elite - Data Engineer
# 535260     Data Engineer                                 Lead Data Engineer
# 213687     Data Engineer  Data Engineer Jobs In Flipdish for Engineering...
# 252564      Data Analyst                                 Research Scientist
# 248548     Data Engineer                             Data Engineer (Remote)
# 260702     Data Engineer                Data Engineer (ETL) (TS/SCI + Poly)
# 704118      Data Analyst  #DISCOVER I 2024 Improvement based in Data Ana...
# 365886      Data Analyst                               Data support analyst
#
#              job_location                               job_via  \
# 665729             Brazil                          via LinkedIn
# ...

# %%
# Problem Statement:Create a new column is_remote that indicates whether the job is remote (True) or not (False) 
#based on the job_work_from_home column.
# Hint: Use boolean indexing to create the new column based on the job_work_from_home column
dfc['is_remote'] =  dfc['job_work_from_home'].apply(lambda x: True if x == 'True' or x == True else False)
dfc
# Out:
#               job_title_short  \
# 108883         Data Scientist
# 334082          Data Engineer
# 365786       Business Analyst
# 366073           Data Analyst
# 108099         Data Scientist
# ...                       ...
# 186163  Senior Data Scientist
# 421728           Data Analyst
# 313161         Data Scientist
# 336301         Data Scientist
# 327439          Data Engineer
#
#                                                 job_title      job_location  \
# 108883                                     Data Scientist     Calabasas, CA
# 334082                                      Data Engineer         Argentina
# 365786                     Hospitality Operations Analyst          Anywhere
# 366073                        Data Analytics Professional       Atlanta, GA
# 108099                       Lead Data Scientist (Hybrid)    Burnsville, MN
# ...                                                   ...               ...
# ...

# %%
dfc['is_remote'] = dfc['job_work_from_home']
dfc
# Out:
#               job_title_short  \
# 108883         Data Scientist
# 334082          Data Engineer
# 365786       Business Analyst
# 366073           Data Analyst
# 108099         Data Scientist
# ...                       ...
# 186163  Senior Data Scientist
# 421728           Data Analyst
# 313161         Data Scientist
# 336301         Data Scientist
# 327439          Data Engineer
#
#                                                 job_title      job_location  \
# 108883                                     Data Scientist     Calabasas, CA
# 334082                                      Data Engineer         Argentina
# 365786                     Hospitality Operations Analyst          Anywhere
# 366073                        Data Analytics Professional       Atlanta, GA
# 108099                       Lead Data Scientist (Hybrid)    Burnsville, MN
# ...                                                   ...               ...
# ...

# %%
# Problem Statement: Create a new column job_posted_year that extracts the year from the job_posted_date column and display the first 5 rows.
# Hint: Use the dt accessor to extract the year from the job_posted_date column.

dfc['job_posted_year'] = dfc.job_posted_date.dt.year
dfc.head(5)
# Out:
#          job_title_short                       job_title    job_location  \
# 108883    Data Scientist                  Data Scientist   Calabasas, CA
# 334082     Data Engineer                   Data Engineer       Argentina
# 365786  Business Analyst  Hospitality Operations Analyst        Anywhere
# 366073      Data Analyst     Data Analytics Professional     Atlanta, GA
# 108099    Data Scientist    Lead Data Scientist (Hybrid)  Burnsville, MN
#
#                                    job_via job_schedule_type  \
# 108883                     via Recruit.net         Full-time
# 334082                        via EchoJobs         Full-time
# 365786  via Goodwin Recruiting | Job Board         Full-time
# 366073                   via CareerBuilder         Full-time
# 108099                     via Recruit.net         Full-time
#
#         job_work_from_home            search_location     job_posted_date  \
# 108883               False  California, United States 2023-01-01 00:02:56
# ...

# %%
# Problem Statement: Drop rows where the salary_year_avg column has missing values and display the first 5 rows of the cleaned DataFrame.
# Hint: Use the dropna method to remove rows with missing values in the salary_year_avg column.
drop_sya = dfc.dropna(subset=['salary_year_avg'])
drop_sya.head(5)
# Out:
#          job_title_short                       job_title    job_location  \
# 108883    Data Scientist                  Data Scientist   Calabasas, CA
# 334082     Data Engineer                   Data Engineer       Argentina
# 365786  Business Analyst  Hospitality Operations Analyst        Anywhere
# 366073      Data Analyst     Data Analytics Professional     Atlanta, GA
# 108099    Data Scientist    Lead Data Scientist (Hybrid)  Burnsville, MN
#
#                                    job_via job_schedule_type  \
# 108883                     via Recruit.net         Full-time
# 334082                        via EchoJobs         Full-time
# 365786  via Goodwin Recruiting | Job Board         Full-time
# 366073                   via CareerBuilder         Full-time
# 108099                     via Recruit.net         Full-time
#
#         job_work_from_home            search_location     job_posted_date  \
# 108883               False  California, United States 2023-01-01 00:02:56
# ...

# %% [markdown]
# #### Pandas: Analyzing

# %%
dfc['job_posted_date'] = pd.to_datetime(dfc['job_posted_date'])

# %%
dfc.describe()
# Out:
#                      job_posted_date  salary_year_avg  job_posted_month  \
# count                          22003     22003.000000      22003.000000
# mean   2023-06-13 01:01:01.813889024    123286.274072          5.886288
# min              2023-01-01 00:02:56     15000.000000          1.000000
# 25%       2023-03-17 14:04:49.500000     90000.000000          3.000000
# 50%              2023-06-11 09:03:27    115000.000000          6.000000
# 75%              2023-08-26 00:41:15    150000.000000          8.000000
# max              2023-12-31 23:40:32    960000.000000         12.000000
# std                              NaN     48312.449482          3.296650
#
#        job_posted_year
# count          22003.0
# mean            2023.0
# min             2023.0
# 25%             2023.0
# 50%             2023.0
# 75%             2023.0
# max             2023.0
# std                0.0

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22003 entries, 108883 to 327439
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  datetime64[ns]
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  company_name           22003 non-null  object
# ...

# %%
dfc.count()
# Out:
# job_title_short          22003
# job_title                22003
# job_location             21723
# job_via                  22003
# job_schedule_type        21987
# job_work_from_home       22003
# search_location          22003
# job_posted_date          22003
# job_no_degree_mention    22003
# job_health_insurance     22003
# job_country              22003
# salary_rate              22003
# salary_year_avg          22003
# company_name             22003
# job_skills               20170
# job_type_skills          20170
# job_posted_month         22003
# is_remote                22003
# job_posted_year          22003
# dtype: int64

# %%
dfc['salary_year_avg'].median()
# Out:
# 115000.0

# %%
dfc.describe()
# Out:
#                      job_posted_date  salary_year_avg  job_posted_month  \
# count                          22003     22003.000000      22003.000000
# mean   2023-06-13 01:01:01.813889024    123286.274072          5.886288
# min              2023-01-01 00:02:56     15000.000000          1.000000
# 25%       2023-03-17 14:04:49.500000     90000.000000          3.000000
# 50%              2023-06-11 09:03:27    115000.000000          6.000000
# 75%              2023-08-26 00:41:15    150000.000000          8.000000
# max              2023-12-31 23:40:32    960000.000000         12.000000
# std                              NaN     48312.449482          3.296650
#
#        job_posted_year
# count          22003.0
# mean            2023.0
# min             2023.0
# 25%             2023.0
# 50%             2023.0
# 75%             2023.0
# max             2023.0
# std                0.0

# %%
dfc['salary_year_avg'].min()
# Out:
# 15000.0

# %%
min_salary = dfc['salary_year_avg'].idxmin()

# %%
min_salary
# Out:
# 665729

# %%
#above the row-index of the minimum entry

# %%
dfc.loc['min_salary']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:175, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'min_salary'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[281], line 1
# ----> 1 dfc.loc['min_salary']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
# ...

# %%
dfc['job_title_short'].value_counts()
# Out:
# job_title_short
# Data Scientist               5922
# Data Analyst                 5451
# Data Engineer                4500
# Senior Data Scientist        1690
# Senior Data Engineer         1591
# Senior Data Analyst          1131
# Business Analyst              610
# Machine Learning Engineer     576
# Software Engineer             467
# Cloud Engineer                 65
# Name: count, dtype: int64

# %%
dfc.groupby('job_title_short')['salary_year_avg'].min()
# Out:
# job_title_short
# Business Analyst             16500.0
# Cloud Engineer               42000.0
# Data Analyst                 25000.0
# Data Engineer                15000.0
# Data Scientist               27000.0
# Machine Learning Engineer    30000.0
# Senior Data Analyst          30000.0
# Senior Data Engineer         35000.0
# Senior Data Scientist        45000.0
# Software Engineer            28000.0
# Name: salary_year_avg, dtype: float64

# %%
dfc.groupby('job_title_short')['salary_year_avg'].median()
# Out:
# job_title_short
# Business Analyst              85000.0
# Cloud Engineer                90000.0
# Data Analyst                  90000.0
# Data Engineer                125000.0
# Data Scientist               127500.0
# Machine Learning Engineer    106415.0
# Senior Data Analyst          111175.0
# Senior Data Engineer         147500.0
# Senior Data Scientist        155500.0
# Software Engineer             99150.0
# Name: salary_year_avg, dtype: float64

# %%
dfc.groupby(['job_title_short','job_country'])['salary_year_avg'].median() # list
# Out:
# job_title_short    job_country
# Business Analyst   Argentina                71100.0
#                    Australia                70000.0
#                    Bangladesh               16500.0
#                    Belgium                  89100.0
#                    Bulgaria                 71925.0
#                                              ...
# Software Engineer  Ukraine                  54000.0
#                    United Arab Emirates     79200.0
#                    United Kingdom           89100.0
#                    United States           130000.0
#                    Vietnam                  53600.0
# Name: salary_year_avg, Length: 598, dtype: float64

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22003 entries, 108883 to 327439
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  datetime64[ns]
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  company_name           22003 non-null  object
# ...

# %%
dfc.groupby('job_title_short')[['salary_year_avg']].median() # aggregate
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %%
dfc.groupby('job_title_short')['salary_year_avg'].agg(['min', 'max', 'median']) # aggregate
# Out:
#                                min       max    median
# job_title_short
# Business Analyst           16500.0  387460.0   85000.0
# Cloud Engineer             42000.0  280000.0   90000.0
# Data Analyst               25000.0  650000.0   90000.0
# Data Engineer              15000.0  525000.0  125000.0
# Data Scientist             27000.0  960000.0  127500.0
# Machine Learning Engineer  30000.0  325000.0  106415.0
# Senior Data Analyst        30000.0  425000.0  111175.0
# Senior Data Engineer       35000.0  425000.0  147500.0
# Senior Data Scientist      45000.0  890000.0  155500.0
# Software Engineer          28000.0  375000.0   99150.0

# %%
# Problem Statement:Calculate the mean of the salary_year_avg column and display the result.
# Hint:Use the mean method to calculate the mean of the salary_year_avg column.
sya = dfc['salary_year_avg'].mean()
sya
# Out:
# 123286.27407182401

# %%
# Problem Statement:Calculate the median of the salary_year_avg column and display the result.
# Hint: Use the median method to calculate the median of the salary_year_avg column.
syam = dfc['salary_year_avg'].median()
syam
# Out:
# 115000.0

# %%
# Problem Statement: Group the DataFrame by job_title_short and calculate the average salary_hour_avg for each job title. Display the result.
# Hint: Use the groupby method to group the DataFrame by job_title_short 
# and then use the mean method to calculate the average salary_hour_avg for each group.
dfc.groupby('job_title_short')[['salary_year_avg']].median() # aggregate
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %%
dfc['salary_hour_avg'] = dfc.salary_year_avg /2080

# %%
dfc['salary_hour_avg'] = np.ceil(dfc['salary_hour_avg']).astype(int)

# %%
ahw = dfc.groupby('job_title_short')['salary_hour_avg'].mean()
ahw
# Out:
# job_title_short
# Business Analyst             44.324590
# Cloud Engineer               54.000000
# Data Analyst                 45.667034
# Data Engineer                63.079556
# Data Scientist               65.923674
# Machine Learning Engineer    61.427083
# Senior Data Analyst          55.329797
# Senior Data Engineer         70.610308
# Senior Data Scientist        74.671598
# Software Engineer            55.098501
# Name: salary_hour_avg, dtype: float64

# %%
# Problem Statement: Find the job title with the lowest average hourly salary and display the job title and the salary.
# Hint: Use the idxmin method to find the index of the minimum value in the salary_hour_avg column 
# and then use iloc to get the corresponding row.
lasr = dfc['salary_hour_avg'].idxmin()
lasr
# Out:
# 380187

# %%
jtwls = dfc.loc[lasr, 'job_title']
jtwls
# Out:
# 'Operations Analyst'

# %%
ls = dfc.loc[lasr, 'salary_hour_avg']
ls
# Out:
# 8

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22003 entries, 108883 to 327439
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  datetime64[ns]
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  company_name           22003 non-null  object
# ...

# %%
print(f"Job Title: {jtwls}, Salary: {ls}")
# Out:
# Job Title: Operations Analyst, Salary: 8

# %%
# Problem Statement: Group the DataFrame by job_country and calculate the total number of job postings for each country. Display the result.
# Hint: Use the groupby method to group the DataFrame by job_country 
# and then use the size method to count the number of job postings for each group.

dfc.groupby(['job_title_short','job_country']).size()
# Out:
# job_title_short    job_country
# Business Analyst   Argentina                 2
#                    Australia                 3
#                    Bangladesh                1
#                    Belgium                   5
#                    Bulgaria                  4
#                                           ...
# Software Engineer  Ukraine                   1
#                    United Arab Emirates      1
#                    United Kingdom            5
#                    United States           157
#                    Vietnam                   2
# Length: 598, dtype: int64

# %% [markdown]
# #### Example: Analyze Salaries Cleaning Inspection Analyzation

# %%
dfc['job_country']
# Out:
# 108883    United States
# 334082        Argentina
# 365786    United States
# 366073    United States
# 108099    United States
#               ...
# 186163    United States
# 421728    United States
# 313161    United States
# 336301            Sudan
# 327439            Sudan
# Name: job_country, Length: 22003, dtype: object

# %%
dfc['job_country'].value_counts()
# Out:
# job_country
# United States             15766
# Sudan                      1623
# India                       582
# Canada                      463
# United Kingdom              287
#                           ...
# Bosnia and Herzegovina        1
# Zambia                        1
# Dominican Republic            1
# Jamaica                       1
# Cambodia                      1
# Name: count, Length: 108, dtype: int64

# %%
dfc['job_country'].value_counts().head(20)
# Out:
# job_country
# United States     15766
# Sudan              1623
# India               582
# Canada              463
# United Kingdom      287
# Germany             257
# France              237
# Poland              200
# Spain               144
# Portugal            131
# Mexico              111
# Israel              103
# Singapore            98
# South Africa         92
# Netherlands          87
# Greece               82
# Australia            74
# Colombia             69
# Philippines          68
# South Korea          63
# Name: count, dtype: int64

# %%
dfc['job_country'].isin(['Brazil'])
# Out:
# 108883    False
# 334082    False
# 365786    False
# 366073    False
# 108099    False
#           ...
# 186163    False
# 421728    False
# 313161    False
# 336301    False
# 327439    False
# Name: job_country, Length: 22003, dtype: bool

# %%
dfc['job_country'].isin(['Brazil']).any()
# Out:
# True

# %%
us_jobs = dfc[dfc['job_country'] == 'United States']
us_jobs
# Out:
#               job_title_short  \
# 108883         Data Scientist
# 365786       Business Analyst
# 366073           Data Analyst
# 108099         Data Scientist
# 78139           Data Engineer
# ...                       ...
# 679         Software Engineer
# 3448     Senior Data Engineer
# 186163  Senior Data Scientist
# 421728           Data Analyst
# 313161         Data Scientist
#
#                                                 job_title      job_location  \
# 108883                                     Data Scientist     Calabasas, CA
# 365786                     Hospitality Operations Analyst          Anywhere
# 366073                        Data Analytics Professional       Atlanta, GA
# 108099                       Lead Data Scientist (Hybrid)    Burnsville, MN
# 78139                   Data Engineer - Revenue Platforms        Boston, NY
# ...                                                   ...               ...
# ...

# %%
us_jobs = us_jobs[us_jobs['salary_year_avg'].notna()] #clean-up

# %%
us_jobs.groupby('job_title_short')['salary_year_avg'].count()
us_jobs
# Out:
#               job_title_short  \
# 108883         Data Scientist
# 365786       Business Analyst
# 366073           Data Analyst
# 108099         Data Scientist
# 78139           Data Engineer
# ...                       ...
# 679         Software Engineer
# 3448     Senior Data Engineer
# 186163  Senior Data Scientist
# 421728           Data Analyst
# 313161         Data Scientist
#
#                                                 job_title      job_location  \
# 108883                                     Data Scientist     Calabasas, CA
# 365786                     Hospitality Operations Analyst          Anywhere
# 366073                        Data Analytics Professional       Atlanta, GA
# 108099                       Lead Data Scientist (Hybrid)    Burnsville, MN
# 78139                   Data Engineer - Revenue Platforms        Boston, NY
# ...                                                   ...               ...
# ...

# %%
us_jobs.groupby('job_title_short')[['salary_year_avg']].min() # double [], [['salary_year_avg']], in list cleans up format
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   35000.0
# Cloud Engineer                     42000.0
# Data Analyst                       25000.0
# Data Engineer                      23496.0
# Data Scientist                     30000.0
# Machine Learning Engineer          44408.5
# Senior Data Analyst                35360.0
# Senior Data Engineer               45000.0
# Senior Data Scientist              55000.0
# Software Engineer                  48982.0

# %%
us_jobs.groupby('job_title_short')[['salary_year_avg']].agg(['min', 'median', 'max', 'count'])
# Out:
#                           salary_year_avg
#                                       min    median       max count
# job_title_short
# Business Analyst                  35000.0   90000.0  387460.0   431
# Cloud Engineer                    42000.0  116100.0  221844.0    20
# Data Analyst                      25000.0   90000.0  375000.0  4350
# Data Engineer                     23496.0  125000.0  525000.0  2915
# Data Scientist                    30000.0  130000.0  960000.0  4553
# Machine Learning Engineer         44408.5  150000.0  315000.0   128
# Senior Data Analyst               35360.0  110000.0  425000.0   913
# Senior Data Engineer              45000.0  150000.0  375000.0  1058
# Senior Data Scientist             55000.0  155000.0  475000.0  1241
# Software Engineer                 48982.0  130000.0  375000.0   157

# %%
us_jobs.groupby('job_title_short')['salary_year_avg'].agg(['min', 'median', 'max', 'count']).sort_values(by='median')
# Out:
#                                min    median       max  count
# job_title_short
# Business Analyst           35000.0   90000.0  387460.0    431
# Data Analyst               25000.0   90000.0  375000.0   4350
# Senior Data Analyst        35360.0  110000.0  425000.0    913
# Cloud Engineer             42000.0  116100.0  221844.0     20
# Data Engineer              23496.0  125000.0  525000.0   2915
# Data Scientist             30000.0  130000.0  960000.0   4553
# Software Engineer          48982.0  130000.0  375000.0    157
# Machine Learning Engineer  44408.5  150000.0  315000.0    128
# Senior Data Engineer       45000.0  150000.0  375000.0   1058
# Senior Data Scientist      55000.0  155000.0  475000.0   1241

# %%
us_jobs.groupby('job_title_short')['salary_year_avg'].agg(['min', 'median', 'max', 'count']).sort_values(by='median') #removed double [] to sort
# Out:
#                                min    median       max  count
# job_title_short
# Business Analyst           35000.0   90000.0  387460.0    431
# Data Analyst               25000.0   90000.0  375000.0   4350
# Senior Data Analyst        35360.0  110000.0  425000.0    913
# Cloud Engineer             42000.0  116100.0  221844.0     20
# Data Engineer              23496.0  125000.0  525000.0   2915
# Data Scientist             30000.0  130000.0  960000.0   4553
# Software Engineer          48982.0  130000.0  375000.0    157
# Machine Learning Engineer  44408.5  150000.0  315000.0    128
# Senior Data Engineer       45000.0  150000.0  375000.0   1058
# Senior Data Scientist      55000.0  155000.0  475000.0   1241

# %%
us_jobs.groupby('job_title_short')['salary_year_avg'].agg(['min', 'median', 'max', 'count']).sort_values(by='median', ascending=False)
# Out:
#                                min    median       max  count
# job_title_short
# Senior Data Scientist      55000.0  155000.0  475000.0   1241
# Machine Learning Engineer  44408.5  150000.0  315000.0    128
# Senior Data Engineer       45000.0  150000.0  375000.0   1058
# Data Scientist             30000.0  130000.0  960000.0   4553
# Software Engineer          48982.0  130000.0  375000.0    157
# Data Engineer              23496.0  125000.0  525000.0   2915
# Cloud Engineer             42000.0  116100.0  221844.0     20
# Senior Data Analyst        35360.0  110000.0  425000.0    913
# Business Analyst           35000.0   90000.0  387460.0    431
# Data Analyst               25000.0   90000.0  375000.0   4350

# %%
import pandas as pd
import matplotlib.pyplot as plt  # we will use this for plotting
import numpy as np

# %%
plt.plot('job_posted_date', 'job_posted_date', data=dfc)

# %%
x = [1, 2, 3, 4]
y = [1, 2, 3, 4]

plt.plot(x, y)
plt.show()

# %%
date_counts = dfc.job_posted_date.value_counts()

# %%
type(date_counts)
# Out:
# pandas.core.series.Series

# %%
date_counts = date_counts.sort_index()

# %%
#above the year-month-day is the index, the values are the core

# %%
date_counts
# Out:
# job_posted_date
# 2023-01-01 00:02:56    1
# 2023-01-01 00:06:13    1
# 2023-01-01 00:17:55    1
# 2023-01-01 00:17:58    1
# 2023-01-01 00:21:09    1
#                       ..
# 2023-12-31 15:00:46    1
# 2023-12-31 16:00:07    1
# 2023-12-31 17:31:57    1
# 2023-12-31 23:40:22    1
# 2023-12-31 23:40:32    1
# Name: count, Length: 21661, dtype: int64

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22003 entries, 108883 to 327439
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  datetime64[ns]
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  company_name           22003 non-null  object
# ...

# %%
plt.plot(date_counts.index, date_counts)

# %%
dfc['job_posted_month']=dfc['job_posted_date'].dt.month

# %%
# above created new column

# %%
monthly_counts=dfc.job_posted_month.value_counts()
monthly_counts = monthly_counts.sort_index()

# %%
monthly_counts
# Out:
# job_posted_month
# 1     2296
# 2     2010
# 3     2204
# 4     1876
# 5     1911
# 6     2331
# 7     2219
# 8     2095
# 9     1246
# 10    1310
# 11    1124
# 12    1381
# Name: count, dtype: int64

# %%
plt.plot(monthly_counts.index, monthly_counts.values)

# %%
series = pd.Series([10,20,30,40,50], index=['a','b','c','d','e'])

# %%
series.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
job_counts = dfc.job_title_short.value_counts()

# %%
plt.bar(job_counts.index, job_counts)
# Out:
# <BarContainer object of 10 artists>

# %%
job_counts=job_counts.sort_values(ascending=True)
plt.barh(job_counts.index, job_counts)
plt.show()

# %% [markdown]
# #### Labeling

# %%
jc=job_country.plot(kind=bar).value_counts().head(5)
plt.title('Location')
plt.xticks(rotation=45, ha='right')
plt.xlabel('')
plt.ylabel('Count', rotation=0, labelpad=30)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[390], line 1
# ----> 1 jc=job_country.plot(kind=bar).value_counts().head(5)
#       2 plt.title('Location')
#       3 plt.xticks(rotation=45, ha='right')
#
# NameError: name 'job_country' is not defined
